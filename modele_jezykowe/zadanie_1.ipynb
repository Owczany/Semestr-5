# %%
from transformers import pipeline, set_seed

generator = pipeline('text-generation', model='flax-community/papuGaPT2', device=0)

print ('Model loaded')
last_prompt = '???'

# while True:

prompt = last_prompt
g = generator(prompt, 
    pad_token_id=generator.tokenizer.eos_token_id)[0]['generated_text']

print (g)
print (50 * '=')
print ()
last_prompt = prompt
# Out:
# Device set to use mps:0
# Model loaded
# ???
# Witam, w związku z tym mam pytanie czy w przypadku gdy w czasie trwania umowy o pracę zawartej na czas nieokreślony, w czasie jej trwania będzie wykonywana umowa o pracę na czas określony, a następnie wykonywana kolejna umowa o pracę na czas określony, to czy taka umowa powinna być zawarta na czas nieokreślony w wymiarze 3/4 etatu?
# Odpowiadając na pytanie: tak, umowa na czas określony będzie taka sama dla każdej osoby, która wykonuje pracę na podstawie umowy o pracę na czas nieokreślony.
# Zaznaczam, że pracuję od 1 listopada 2006 r. na umowę o pracę na czas nieokreślony (w sumie na okres od 1 stycznia 2007 r. do 31 października 2007 r.)
# Czy mając umowę o pracę na czas określony zawartą na czas określony mogę ją rozwiązać w terminie 30 dni?
# Witam, czy w przypadku, gdy w czasie trwania umowy o pracę zawartej na czas określony, w czasie jej trwania będzie wykonywana praca na podstawie umowy o pracę na czas określony, a następnie wykonywana kolejna umowa o pracę na czas określony, to czy taka umowa powinna być zawarta na czas określony w wymiarze 3/4 etatu, czy też na czas określony w wymiarze 1/2 etatu?
# Jestem zatrudniony na umowę-zlecenie na podstawie umowy o pracę na czas nieokreślony (umowa o dzieło). W czasie trwania
# ==================================================
