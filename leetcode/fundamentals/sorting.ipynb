# %%
import numpy as np

nums = np.random.randint(-100, 100, size=100)
intervals = np.random.randint(-100, 100, size=(100, 2))

# print(nums)
# print(intervals)

sorted_intervals = sorted(intervals, key=lambda x: (x[0], x[1]))
nums.sort()
intervals.sort()


# print(nums)
print(sorted_intervals)
# Out:
# [array([-99, -38]), array([-95, -82]), array([-93,  69]), array([-92, -63]), array([-91,  58]), array([-88,  -1]), array([-87,   6]), array([-86, -78]), array([-86,  30]), array([-87, -85]), array([-84,  -3]), array([-84,  93]), array([-80,  45]), array([-76,  68]), array([-76,  75]), array([-73, -49]), array([-73, -22]), array([-73,  22]), array([-99, -70]), array([-68,  11]), array([-67, -16]), array([-63,  48]), array([-60, -18]), array([-75, -59]), array([-59, -36]), array([-58,  92]), array([-58,  97]), array([-81, -57]), array([-95, -56]), array([-54,  78]), array([-47,  87]), array([-66, -46]), array([-45,  81]), array([-44,  -5]), array([-57, -41]), array([-41,  83]), array([-93, -37]), array([-37, -19]), array([-37, -18]), array([-74, -36]), array([-36, -33]), array([-50, -29]), array([-29,  44]), array([-28,  78]), array([-30, -24]), array([-23,  98]), array([-64, -22]), array([-20,  96]), array([-56, -19]), array([-77, -17]), array([-28, -14]), array([-13,  45]), array([-1
# ...

# %%
text = 'abc'

print(text[:1])
# Out:
# a
